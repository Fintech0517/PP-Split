# %% [markdown]
# # Label inference 示例代码

# %% [markdown]
# ## 不添加保护直接进行攻击

# %%
import sys
sys.path.append('/home/yangjirui/data/VFL/PP-Split/')
from ppsplit.attacks.label_inference.label_leakage import main

data_dir = './mini_creditcard.csv'

main(data_dir)
# Out:
# device is  cuda:0
# Examples:
#     Total: 2848
#     Positive: 5 (0.18% of total)
#
# Training labels shape: (1822,)
# Validation labels shape: (456,)
# Test labels shape: (570,)
# Training features shape: (1822, 31)
# Validation features shape: (456, 31)
# Test features shape: (570, 31)
# epoch=0, loss: 0.003597488088512929, auc: 0.09730621220450797
# epoch=1, loss: 0.003437429320325926, auc: 0.1343228880337181
# epoch=2, loss: 0.0032887389270111313, auc: 0.16785779732453732
# epoch=3, loss: 0.003154095606272827, auc: 0.19277991570459957
# epoch=4, loss: 0.0030173558062498687, auc: 0.23529411764705876
# epoch=5, loss: 0.0028889032730201516, auc: 0.29246838922484875
# epoch=6, loss: 0.0027624296159802692, auc: 0.32435404068169316
# epoch=7, loss: 0.002633179659928179, auc: 0.34561114165292284
# epoch=8, loss: 0.0025086459201055793, auc: 0.38079530877771667
# epoch=9, loss: 0.0023975829724012104, auc: 0.4280740333516584
# epoch=10, loss: 0.002268345849356706, auc: 0.4280740333516584
# ...

# %% [markdown]
# ## 添加保护的攻击结果
#
# 可选的攻击方法有：
#
#
# `ISO`,`MAX_NORM`和`Marvell`
# 注意ISO有超参数可选

# %% [markdown]
# ### 1. iso噪声

# %%
import sys
sys.path.append('/home/yangjirui/data/VFL/PP-Split/')
from ppsplit.attacks.label_inference.label_leakage_protect import main_protect
# 
data_dir = './mini_creditcard.csv'

main_protect(data_dir,"ISO", 0.005)
# Out:
# device is  cpu
# Examples:
#     Total: 2848
#     Positive: 5 (0.18% of total)
#
# Training labels shape: (1822,)
# Validation labels shape: (456,)
# Test labels shape: (570,)
# Training features shape: (1822, 31)
# Validation features shape: (456, 31)
# Test features shape: (570, 31)
# epoch=0, loss: 0.005328802039818754, auc: 0.07623236210371998
# epoch=1, loss: 0.004987545262916156, auc: 0.10445299615173172
# epoch=2, loss: 0.004672392109783228, auc: 0.10097122961334067
# epoch=3, loss: 0.00437641056497692, auc: 0.12039582188015396
# epoch=4, loss: 0.00410157491509143, auc: 0.12919186366135238
# epoch=5, loss: 0.003826483342444408, auc: 0.13065787062488546
# epoch=6, loss: 0.003564406966953179, auc: 0.16107751511819682
# epoch=7, loss: 0.0033492557709802057, auc: 0.1689573025471871
# epoch=8, loss: 0.003146644053438814, auc: 0.18178486347810147
# epoch=9, loss: 0.0029338224964473216, auc: 0.2002932013927066
# epoch=10, loss: 0.0027334708916402933, auc: 0.20780648708081365
# ...

# %% [markdown]
# ### 2.MAX_NORM防御

# %%
import sys
sys.path.append('/home/yangjirui/data/VFL/PP-Split/')
from ppsplit.attacks.label_inference.label_leakage_protect import main_protect
# 
data_dir = './mini_creditcard.csv'

main_protect(data_dir,"MAX_NORM")
# Out:
# device is  cpu
# Examples:
#     Total: 2848
#     Positive: 5 (0.18% of total)
#
# Training labels shape: (1822,)
# Validation labels shape: (456,)
# Test labels shape: (570,)
# Training features shape: (1822, 31)
# Validation features shape: (456, 31)
# Test features shape: (570, 31)
# epoch=0, loss: 0.005480568165492334, auc: 0.7438152831225948
# epoch=1, loss: 0.004988844775756937, auc: 0.831592450064138
# epoch=2, loss: 0.004557738640789308, auc: 0.8975627634231262
# epoch=3, loss: 0.0041570589586369675, auc: 0.9490562580172256
# epoch=4, loss: 0.0038086456924914837, auc: 0.9666483415796225
# epoch=5, loss: 0.0034578957614200567, auc: 0.9704966098588969
# epoch=6, loss: 0.0031342121069673646, auc: 0.9831409199193697
# epoch=7, loss: 0.0028506718201722196, auc: 0.9879054425508521
# epoch=8, loss: 0.0025789437637391437, auc: 0.9928532160527762
# epoch=9, loss: 0.002320494748683047, auc: 0.9860729338464358
# epoch=10, loss: 0.0020857830000936693, auc: 0.9890049477735019
# ...

# %% [markdown]
# ### 3.Marvell防御

# %%
import sys
sys.path.append('/home/yangjirui/data/VFL/PP-Split/')
from ppsplit.attacks.label_inference.label_leakage_protect import main_protect
# 
data_dir = './mini_creditcard.csv'

main_protect(data_dir,"Marvell")
# Out:
# device is  cpu
# Examples:
#     Total: 2848
#     Positive: 5 (0.18% of total)
#
# Training labels shape: (1822,)
# Validation labels shape: (456,)
# Test labels shape: (570,)
# Training features shape: (1822, 31)
# Validation features shape: (456, 31)
# Test features shape: (570, 31)
# epoch=0, loss: 0.005814325598659649, auc: 0.2331315354980738
# epoch=1, loss: 0.005376736665528815, auc: 0.23434232250963127
# epoch=2, loss: 0.004953221062232278, auc: 0.3033571821684095
# epoch=3, loss: 0.004574032866707292, auc: 0.4135388002201431
# epoch=4, loss: 0.004182484705226231, auc: 0.502586681342873
# epoch=5, loss: 0.003822979833762759, auc: 0.5200880572372042
# epoch=6, loss: 0.0034644580981825017, auc: 0.5496973032471106
# epoch=7, loss: 0.0031208449618104935, auc: 0.6002201430930105
# epoch=8, loss: 0.0027925597737718695, auc: 0.6580077050082555
# epoch=9, loss: 0.002494694230391516, auc: 0.7051183269124932
# epoch=10, loss: 0.0022309539379818328, auc: 0.7198679141441938
# ...
